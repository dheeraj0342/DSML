# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
tips = pd.read_csv('./tips.csv')

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size',kind='scatter')

# %%
gap= pd.read_csv('./gap.csv')
gap
# Out:
#       Unnamed: 0      country continent  year  lifeExp       pop   gdpPercap
# 0              0  Afghanistan      Asia  1952   28.801   8425333  779.445314  \
# 1              1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2              2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3              3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4              4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...          ...          ...       ...   ...      ...       ...         ...
# 1699        1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700        1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701        1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702        1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703        1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
#      iso_alpha  iso_num
# ...

# %%
temp_df = gap[gap['country']=='India']
sns.relplot(data=temp_df,x='year',y='lifeExp',kind='line')

# %%
temp_df = gap[gap['country'].isin(['India','Brazil','Germany'])]
sns.relplot(data=temp_df,x='year',y='lifeExp',kind='line',hue='country')

# %%
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='line',hue='country',col_wrap=3,col='continent')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex')

# %%
sns.displot(data=tips,x='total_bill',kind='hist')

# %%
sns.histplot(data=tips,x='total_bill',kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,x='total_bill',kind='hist',hue='sex',element='step')

# %%
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True)

# %%
# rug plot
sns.displot(data=tips,x='total_bill',kind='kde',rug=True)

# %%
gap=gap.pivot(index='country',columns='year',values='lifeExp')
sns.heatmap(gap)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
gap = pd.read_csv('./gap.csv')
team_df =gap.pivot(index='country',columns='year',values='lifeExp')
plt.figure(figsize=(10,5))
sns.heatmap(team_df,annot=True)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
iris = pd.read_csv('./iris.csv')
sns.clustermap(iris.iloc[:,0:4],cmap='summer')

# %%
tips = pd.read_csv('./tips.csv')
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.stripplot(data=tips,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x='day',y='tip',kind='swarm',hue='sex')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,x='sex',y='tip')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='bar',hue='sex')

# %%
sns.catplot(data=tips,x='sex',y='total_bill',kind='point',hue='smoker')

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='violin',split=True,hue='smoker')

# %%
sns.countplot(data=tips,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.residplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
