# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# types of data
# 1. categorical data -> nominal, ordinal
# 2. numerical data -> discrete, continuous

# %%
price = [40000, 30000, 38000, 40000, 25500]
year = [2020, 2021, 2022, 2023, 2024]
plt.plot(year, price)

# %%
data = pd.read_csv('./sharma-kohli.csv')
plt.plot(data['index'], data['V Kohli'], label='V Kohli', color='red')
plt.plot(data['index'], data['RG Sharma'], label='RG Sharma', color='blue')
