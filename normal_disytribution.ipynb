# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

sample = normal(loc = 50, scale = 5, size = 1000)

# %%
sample.mean()
# Out:
# 49.93636275741755

# %%
plt.hist(sample, bins = 30, edgecolor = 'black')
# Out:
# (array([ 1.,  0.,  3.,  5.,  2.,  9., 22., 16., 30., 41., 55., 63., 84.,
#         87., 91., 89., 81., 77., 64., 62., 45., 24., 17., 13., 11.,  4.,
#          2.,  1.,  0.,  1.]),
#  array([32.95554217, 34.09576621, 35.23599024, 36.37621428, 37.51643832,
#         38.65666236, 39.79688639, 40.93711043, 42.07733447, 43.2175585 ,
#         44.35778254, 45.49800658, 46.63823061, 47.77845465, 48.91867869,
#         50.05890273, 51.19912676, 52.3393508 , 53.47957484, 54.61979887,
#         55.76002291, 56.90024695, 58.04047098, 59.18069502, 60.32091906,
#         61.4611431 , 62.60136713, 63.74159117, 64.88181521, 66.02203924,
#         67.16226328]),
#  <BarContainer object of 30 artists>)

# %%
sample_mean = sample.mean()
sample_std = sample.std()
sample_std
# Out:
# 4.963888822042974

# %%
import seaborn as sns
sns.displot(sample)

# %%
sample1 = normal(loc = 50, scale = 5, size = 1000)
sample2 = normal(loc = 50, scale = 5, size = 1000)
sample = np.hstack((sample1, sample2))

# %%
sample
# Out:
# array([58.44934132, 45.29383169, 46.53165907, ..., 45.6634043 ,
#        53.68569539, 50.18296331])

# %%
sns.kdeplot(sample.reshape(1000), color = 'red', bw_adjust=2)
# Out:
# <Axes: ylabel='Density'>

# %%
import pandas as pd
titanic = pd.read_csv('./test.csv')
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex
# 0          892       3                              Kelly, Mr. James    male  \
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
